# %% [markdown]
# <a href="https://colab.research.google.com/github/K-107/deep-learning-with-python-notebooks/blob/tf2/8.4-generating-YOONA-images-with-vaes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import tensorflow as tf

tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # 이미지 생성
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/deep-learning-with-python/) 책의 8장 4절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다. 이 노트북의 설명은 케라스 버전 2.2.2에 맞추어져 있습니다. 케라스 최신 버전이 릴리스되면 노트북을 다시 테스트하기 때문에 설명과 코드의 결과가 조금 다를 수 있습니다.
#
# ---
#
# ## 변이형 오토인코더
#
# 2013년 12월 킹마와 웰링 그리고 2014년 1월 르젠드, 무함마드, 위스트라가 동시에 발견한 변이형 오토인코더는 생성 모델의 한 종류로 개념 벡터를 사용해 이미지를 변형하는데 아주 적절합니다. 오토인코더는 입력을 저차원 잠재 공간으로 인코딩한 다음 디코딩하여 복원하는 네트워크입니다. 변이형 오토인코더는 딥러닝과 베이즈 추론의 아이디어를 혼합한 오토인코더의 최신 버전입니다.
#
# 고전적인 오토인코더는 이미지를 입력받아 인코더 모듈을 사용해 잠재 벡터 공간으로 매핑합니다. 그다음 디코더 모듈을 사용해 원본 이미지와 동일한 차원으로 복원하여 출력합니다. 오토인코더는 입력 이미지와 동일한 이미지를 타깃 데이터로 사용하여 훈련합니다. 다시 말해 오토인코더는 원본 입력을 재구성하는 방법을 학습합니다. 코딩(인코더의 출력)에 여러 제약을 가하면 오토인코더가 더 흥미로운 혹은 덜 흥미로운 잠재 공간의 표현을 학습합니다. 일반적으로 코딩이 저차원이고 희소(0이 많은)하도록 제약을 가합니다. 이런 경우 인코더는 입력 데이터의 정보를 적은 수의 비트에 압축하기 위해 노력합니다.

# %% [markdown]
# ![Autoencoder](https://s3.amazonaws.com/book.keras.io/img/ch8/autoencoder.jpg)

# %% [markdown]
# 현실적으로 이런 전통적인 오토인코더는 특별히 유용하거나 구조화가 잘 된 잠재 공간을 만들지 못합니다. 압축도 아주 뛰어나지 않습니다. 이런 이유 때문에 시대의 흐름에서 대부분 멀어졌습니다. VAE는 오토인코더에 약간의 통계 기법을 추가하여 연속적이고 구조적인 잠재 공간을 학습하도록 만들었습니다. 결국 이미지 생성을 위한 강력한 도구로 탈바꿈되었습니다.
#
# 입력 이미지를 잠재 공간의 고정된 코딩으로 압축하는 대신 VAE는 이미지를 어떤 통계 분포의 파라미터로 변환합니다. 이는 입력 이미지가 통계적 과정을 통해서 생성되었다고 가정하여 인코딩과 디코딩하는 동안 무작위성이 필요하다는 것을 의미합입니다. VAE는 평균과 분산 파라미터를 사용해 이 분포에서 무작위로 하나의 샘플을 추출합니다. 이 샘플을 디코딩하여 원본 입력으로 복원합니다(그림 8-13 참조). 이런 무작위한 과정은 안정성을 향상하고 잠재 공간 어디서든 의미있는 표현을 인코딩하도록 만듭니다. 즉 잠재 공간에서 샘플링한 모든 포인트는 유효한 출력으로 디코딩됩니다.

# %% [markdown]
# ![VAE](https://s3.amazonaws.com/book.keras.io/img/ch8/vae.png)

# %% [markdown]
# 기술적으로 보면 VAE는 다음과 같이 작동합니다. 먼저 인코더 모듈이 입력 샘플 `imput_img`을 잠재 공간의 두 파라미터 `z_mean`과 `z_log_variance`로 변환합니다. 그다음 입력 이미지가 생성되었다고 가정한 잠재 공간의 정규 분포에서 포인트 `z`를 `z = z_mean + exp(0.5 * z_log_variance) * epsilon`와 같이 무작위로 샘플링합니다. `epsilon`는 작은 값을 가진 랜덤 텐서입니다. 마지막으로 디코더 모듈은 잠재 공간의 이 포인트를 원본 입력 이미지로 매핑하여 복원합니다. `epsilon`이 무작위로 만들어지기 때문에 `input_img`를 인코딩한 잠재 공간의 위치(`z_mean`)에 가까운 포인트는 `input_img`와 비슷한 이미지로 디코딩될 것입니다. 이는 잠재 공간을 연속적이고 의미 있는 공간으로 만들어 줍니다. 잠재 공간에서 가까운 두 개의 포인트는 아주 비슷한 이미지로 디코딩될 것입니다. 잠재 공간의 이런 저차원 연속성은 잠재 공간에서 모든 방향이 의미있는 데이터 변화의 축을 인코딩하도록 만듭니다. 결국 잠재 공간은 매우 구조적이고 개념 벡터로 다루기에 매우 적합해집니다.
#
# VAE의 파라미터는 두 개의 손실 함수로 훈련합니다. 디코딩된 샘플이 원본 입력과 동일하도록 만드는 재구성 손실과 잠재 공간을 잘 형성하고 훈련 데이터에 과대적합을 줄이는 규제 손실입니다.
#
# 케라스의 VAE 구현을 간단히 살펴보겠습니다. 개략적으로 보면 다음과 같습니다:

# %% [markdown]
# ```python
# # 입력을 평균과 분산 파라미터로 인코딩합니다
# z_mean, z_log_variance = encoder(input_img)
#
# # 무작위로 선택한 작은 epsilon 값을 사용해 잠재 공간의 포인트를 뽑습니다
# z = z_mean + exp(z_log_variance) * epsilon
#
# # z를 이미지로 디코딩합니다
# reconstructed_img = decoder(z)
#
# # 모델 객체를 만듭니다
# model = Model(input_img, reconstructed_img)
#
# # 입력 이미지와 재구성 이미지를 매핑한 오토인코더 모델을 훈련합니다.
# ```

# %% [markdown]
# 다음 코드는 이미지를 잠재 공간 상의 확률 분포 파라미터로 매핑하는 인코더 네트워크입니다. 입력 이미지 `x`를 두 벡터 `z_mean`과 `z_log_var`로 매핑하는 간단한 컨브넷입니다.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
import numpy as np

img_shape = (200, 200, 1)
batch_size = 16
latent_dim = 2  # 잠재 공간의 차원: 2D 평면

input_img = keras.Input(shape=img_shape)

x = layers.Conv2D(32, 3, # (28, 28, 32)
                  padding='same', activation='relu')(input_img)
x = layers.Conv2D(64, 3, # (28, 28, 64)
                  padding='same', activation='relu',
                  strides=(2, 2))(x) # img_shape = (28, 28, 1)가 (14, 14, 64)가 된다.
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
shape_before_flattening = K.int_shape(x) # (None, 14, 14, 64)

x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)

z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)

# %% [markdown]
# 다음은 `z_mean`과 `z_log_var`를 사용하는 코드입니다. 이 두 파라미터가 `input_img`를 생성한 통계 분포의 파라미터라고 가정하고 잠재 공간 포인트 `z`를 생성합니다. 여기에서 (케라스의 백엔드 기능으로 만든) 일련의 코드를 `Lambda` 층으로 감쌉니다. 케라스에서는 모든 것이 층이므로 기본 층을 사용하지 않은 코드는 `Lambda`로 (또는 직접 만든 층으로) 감싸야 합니다.

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])

# %% [markdown]
# 다음 코드는 디코더 구현입니다. 벡터 `z`를 이전 특성 맵 차원으로 크기를 바꾸고 몇 개의 합성곱 층을 사용해 최종 출력 이미지를 만듭니다. 최종 이미지는 원본 `input_img`와 차원이 같습니다.

# %%
# Input에 z를 주입합니다
decoder_input = layers.Input(K.int_shape(z)[1:]) # (None, 14, 14, 64)이라 [1:]을 해서 (14, 14, 64)한다.

# 입력을 업샘플링합니다
x = layers.Dense(np.prod(shape_before_flattening[1:]), # shape_before_flattening[1:]는 (14, 14, 64)이므로
                 activation='relu')(decoder_input)     # 모든 요소를 곱한 14*14*64=12544가 np.prod(shape_before_flattening[1:])이다.
                                                       #  https://aigong.tistory.com/47
                                                       # 즉 노드를 12544개 준다.
# 인코더 모델의 마지막 Flatten 층 직전의 특성 맵과 같은 크기를 가진 특성 맵으로 z의 크기를 바꿉니다
x = layers.Reshape(shape_before_flattening[1:])(x) # 12544를 (14, 14, 64)로 바꿔준다.

# Conv2DTranspose 층과 Conv2D 층을 사용해 z를 원본 입력 이미지와 같은 크기의 특성 맵으로 디코딩합니다
# 전치를 그냥 반대라고 생각해서 Conv2D의 입력과 출력이 바꼈다고 생각하자!
x = layers.Conv2DTranspose(32, 3,
                           padding='same', activation='relu',
                           strides=(2, 2))(x) # 반대로 2배로 늘려준다.
x = layers.Conv2D(1, 3,
                  padding='same', activation='sigmoid')(x)
# 특성 맵의 크기가 원본 입력과 같아집니다

# 디코더 모델 객체를 만듭니다
decoder = Model(decoder_input, x)

# 모델에 z를 주입하면 디코딩된 z를 출력합니다
z_decoded = decoder(z)

# %%
decoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 640000)            1920000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 200, 200, 32)      18464
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 200, 200, 1)       289
# =================================================================
# Total params: 1,938,753
# Trainable params: 1,938,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 일반적인 샘플 기준의 함수인 `loss(y_true, y_pred)` 형태는 VAE의 이중 손실에 맞지 않습니다. `add_loss` 내장 메서드를 사용하는 층을 직접 만들어 임의의 손실을 정의하겠습니다.

# %%
class CustomVariationalLayer(keras.layers.Layer):

    def vae_loss(self, x, z_decoded):
        x = K.flatten(x)
        z_decoded = K.flatten(z_decoded)
        xent_loss = keras.metrics.binary_crossentropy(x, z_decoded)
        kl_loss = -5e-4 * K.mean(
            1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        z_decoded = inputs[1]
        loss = self.vae_loss(x, z_decoded)
        self.add_loss(loss, inputs=inputs)
        # 출력 값을 사용하지 않습니다
        return x

# 입력과 디코딩된 출력으로 이 층을 호출하여 모델의 최종 출력을 얻습니다
y = CustomVariationalLayer()([input_img, z_decoded])

# %% [markdown]
# 이제 모델 객체를 만들고 훈련할 준비가 되었습니다. 층에서 손실을 직접 다루기 때문에 `compile` 메서드에서 손실을 지정하지 않습니다(`loss=None`). 그 결과 훈련하는 동안 타깃 데이터를 전달하지 않아도 됩니다(다음 코드처럼 모델의 `fit` 메서드에 `x_train`만 전달합니다).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/vae
# Out:
# /content/drive/MyDrive/vae

# %%
! mkdir /content/drive/MyDrive/vae/data

# %%
# !unzip yoona_0.zip -d ./data
# Out:
# Archive:  yoona_0.zip
#    creating: ./data/yoona_0/
#   inflating: ./data/yoona_0/1.jpg
#   inflating: ./data/yoona_0/10.jpg
#   inflating: ./data/yoona_0/100.jpg
#   inflating: ./data/yoona_0/101.jpg
#   inflating: ./data/yoona_0/102.jpg
#   inflating: ./data/yoona_0/103.jpg
#   inflating: ./data/yoona_0/104.jpg
#   inflating: ./data/yoona_0/105.jpg
#   inflating: ./data/yoona_0/107.jpg
#   inflating: ./data/yoona_0/108.jpg
#   inflating: ./data/yoona_0/11.jpg
#   inflating: ./data/yoona_0/110.jpg
#   inflating: ./data/yoona_0/111.jpg
#   inflating: ./data/yoona_0/112.jpg
#   inflating: ./data/yoona_0/113.jpg
#   inflating: ./data/yoona_0/115.jpg
#   inflating: ./data/yoona_0/116.jpg
#   inflating: ./data/yoona_0/117.jpg
#   inflating: ./data/yoona_0/118.jpg
#   inflating: ./data/yoona_0/119.jpg
#   inflating: ./data/yoona_0/12.jpg
#   inflating: ./data/yoona_0/120.jpg
#   inflating: ./data/yoona_0/121.jpg
#   inflating: ./data/yoona_0/122.jpg
#   inflating: ./data/yoona_0/123.jpg
#   inflating: ./data/yoona_0/124.jpg
#   inflating: ./data/yoona_0/125.jpg
#   inflating: ./data/yoona_0/126.jpg
#   inflating: ./data/yoona_0/127.jpg
#   inflating: ./data/yoona_0/128.jpg
#   inflating: ./data/yoona_0/129.jpg
#   inflating: ./data/yoona_0/13.jpg
#   inflating: ./data/yoona_0/131.jpg
#   inflating: ./data/yoona_0/132.jpg
#   inflating: ./data/yoona_0/133.jpg
#   inflating: ./data/yoona_0/134.jpg
#   inflating: ./data/yoona_0/135.jpg
#   inflating: ./data/yoona_0/136.jpg
#   inflating: ./data/yoona_0/137.jpg
#   inflating: ./data/yoona_0/138.jpg
#   inflating: ./data/yoona_0/139.jpg
#   inflating: ./data/yoona_0/14.jpg
#   inflating: ./data/yoona_0/140.jpg
#   inflating: ./data/yoona_0/141.jpg
#   inflating: ./data/yoona_0/142.jpg
#   inflating: ./data/yoona_0/144.jpg
#   inflating: ./data/yoona_0/145.jpg
#   inflating: ./data/yoona_0/146.jpg
#   inflating: ./data/yoona_0/149.jpg
#   inflating: ./data/yoona_0/15.jpg
#   inflating: ./data/yoona_0/150.jpg
#   inflating: ./data/yoona_0/151.jpg
#   inflating: ./data/yoona_0/152.jpg
#   inflating: ./data/yoona_0/153.jpg
#   inflating: ./data/yoona_0/154.jpg
#   inflating: ./data/yoona_0/155.jpg
#   inflating: ./data/yoona_0/156.jpg
#   inflating: ./data/yoona_0/157.jpg
#   inflating: ./data/yoona_0/158.jpg
#   inflating: ./data/yoona_0/159.jpg
#   inflating: ./data/yoona_0/16.jpg
#   inflating: ./data/yoona_0/160.jpg
#   inflating: ./data/yoona_0/161.jpg
#   inflating: ./data/yoona_0/162.jpg
#   inflating: ./data/yoona_0/163.jpg
#   inflating: ./data/yoona_0/164.jpg
#   inflating: ./data/yoona_0/165.jpg
#   inflating: ./data/yoona_0/166.jpg
#   inflating: ./data/yoona_0/167.jpg
#   inflating: ./data/yoona_0/168.jpg
#   inflating: ./data/yoona_0/169.jpg
#   inflating: ./data/yoona_0/17.jpg
#   inflating: ./data/yoona_0/170.jpg
#   inflating: ./data/yoona_0/171.jpg
#   inflating: ./data/yoona_0/172.jpg
#   inflating: ./data/yoona_0/174.jpg
#   inflating: ./data/yoona_0/175.jpg
#   inflating: ./data/yoona_0/176.jpg
#   inflating: ./data/yoona_0/177.jpg
#   inflating: ./data/yoona_0/178.jpg
#   inflating: ./data/yoona_0/179.jpg
#   inflating: ./data/yoona_0/180.jpg
#   inflating: ./data/yoona_0/181.jpg
#   inflating: ./data/yoona_0/182.jpg
#   inflating: ./data/yoona_0/184.jpg
#   inflating: ./data/yoona_0/185.jpg
#   inflating: ./data/yoona_0/186.jpg
#   inflating: ./data/yoona_0/187.jpg
#   inflating: ./data/yoona_0/188.jpg
#   inflating: ./data/yoona_0/189.jpg
#   inflating: ./data/yoona_0/19.jpg
#   inflating: ./data/yoona_0/190.jpg
#   inflating: ./data/yoona_0/191.jpg
#   inflating: ./data/yoona_0/193.jpg
#   inflating: ./data/yoona_0/194.jpg
#   inflating: ./data/yoona_0/195.jpg
#   inflating: ./data/yoona_0/196.jpg
#   inflating: ./data/yoona_0/197.jpg
#   inflating: ./data/yoona_0/198.jpg
#   inflating: ./data/yoona_0/199.jpg
#   inflating: ./data/yoona_0/2.jpg
#   inflating: ./data/yoona_0/20.jpg
#   inflating: ./data/yoona_0/200.jpg
#   inflating: ./data/yoona_0/201.jpg
#   inflating: ./data/yoona_0/21.jpg
#   inflating: ./data/yoona_0/22.jpg
#   inflating: ./data/yoona_0/23.jpg
#   inflating: ./data/yoona_0/24.jpg
#   inflating: ./data/yoona_0/25.jpg
#   inflating: ./data/yoona_0/26.jpg
#   inflating: ./data/yoona_0/27.jpg
#   inflating: ./data/yoona_0/28.jpg
#   inflating: ./data/yoona_0/29.jpg
#   inflating: ./data/yoona_0/3.jpg
#   inflating: ./data/yoona_0/30.jpg
#   inflating: ./data/yoona_0/31.jpg
#   inflating: ./data/yoona_0/32.jpg
#   inflating: ./data/yoona_0/33.jpg
#   inflating: ./data/yoona_0/34.jpg
#   inflating: ./data/yoona_0/35.jpg
#   inflating: ./data/yoona_0/36.jpg
#   inflating: ./data/yoona_0/37.jpg
#   inflating: ./data/yoona_0/38.jpg
#   inflating: ./data/yoona_0/39.jpg
#   inflating: ./data/yoona_0/4.jpg
#   inflating: ./data/yoona_0/40.jpg
#   inflating: ./data/yoona_0/41.jpg
#   inflating: ./data/yoona_0/42.jpg
#   inflating: ./data/yoona_0/43.jpg
#   inflating: ./data/yoona_0/44.jpg
#   inflating: ./data/yoona_0/46.jpg
#   inflating: ./data/yoona_0/47.jpg
#   inflating: ./data/yoona_0/48.jpg
#   inflating: ./data/yoona_0/49.jpg
#   inflating: ./data/yoona_0/5.jpg
#   inflating: ./data/yoona_0/50.jpg
#   inflating: ./data/yoona_0/51.jpg
#   inflating: ./data/yoona_0/52.jpg
#   inflating: ./data/yoona_0/53.jpg
#   inflating: ./data/yoona_0/54.jpg
#   inflating: ./data/yoona_0/55.jpg
#   inflating: ./data/yoona_0/56.jpg
#   inflating: ./data/yoona_0/57.jpg
#   inflating: ./data/yoona_0/58.jpg
#   inflating: ./data/yoona_0/59.jpg
#   inflating: ./data/yoona_0/6.jpg
#   inflating: ./data/yoona_0/60.jpg
#   inflating: ./data/yoona_0/61.jpg
#   inflating: ./data/yoona_0/62.jpg
#   inflating: ./data/yoona_0/63.jpg
#   inflating: ./data/yoona_0/64.jpg
#   inflating: ./data/yoona_0/65.jpg
#   inflating: ./data/yoona_0/67.jpg
#   inflating: ./data/yoona_0/68.jpg
#   inflating: ./data/yoona_0/69.jpg
#   inflating: ./data/yoona_0/7.jpg
#   inflating: ./data/yoona_0/70.jpg
#   inflating: ./data/yoona_0/71.jpg
#   inflating: ./data/yoona_0/72.jpg
#   inflating: ./data/yoona_0/73.jpg
#   inflating: ./data/yoona_0/74.jpg
#   inflating: ./data/yoona_0/75.jpg
#   inflating: ./data/yoona_0/76.jpg
#   inflating: ./data/yoona_0/78.jpg
#   inflating: ./data/yoona_0/79.jpg
#   inflating: ./data/yoona_0/8.jpg
#   inflating: ./data/yoona_0/80.jpg
#   inflating: ./data/yoona_0/81.jpg
#   inflating: ./data/yoona_0/83.jpg
#   inflating: ./data/yoona_0/84.jpg
#   inflating: ./data/yoona_0/85.jpg
#   inflating: ./data/yoona_0/86.jpg
#   inflating: ./data/yoona_0/87.jpg
#   inflating: ./data/yoona_0/88.jpg
#   inflating: ./data/yoona_0/89.jpg
#   inflating: ./data/yoona_0/9.jpg
#   inflating: ./data/yoona_0/90.jpg
#   inflating: ./data/yoona_0/91.jpg
#   inflating: ./data/yoona_0/92.jpg
#   inflating: ./data/yoona_0/94.jpg
#   inflating: ./data/yoona_0/95.jpg
#   inflating: ./data/yoona_0/96.jpg
#   inflating: ./data/yoona_0/97.jpg
#   inflating: ./data/yoona_0/98.jpg
#   inflating: ./data/yoona_0/99.jpg

# %%
import os

# %cd './data/yoona_0'

images = os.listdir()
images
# Out:
# /content/drive/My Drive/vae/data/yoona_0
# ['1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '101.jpg',
#  '102.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '107.jpg',
#  '108.jpg',
#  '11.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '115.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '12.jpg',
#  '120.jpg',
#  '121.jpg',
#  '122.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '13.jpg',
#  '131.jpg',
#  '132.jpg',
#  '133.jpg',
#  '134.jpg',
#  '135.jpg',
#  '136.jpg',
#  '137.jpg',
#  '138.jpg',
#  '139.jpg',
#  '14.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '144.jpg',
#  '145.jpg',
#  '146.jpg',
#  '149.jpg',
#  '15.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '159.jpg',
#  '16.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '163.jpg',
#  '164.jpg',
#  '165.jpg',
#  '166.jpg',
#  '167.jpg',
#  '168.jpg',
#  '169.jpg',
#  '17.jpg',
#  '170.jpg',
#  '171.jpg',
#  '172.jpg',
#  '174.jpg',
#  '175.jpg',
#  '176.jpg',
#  '177.jpg',
#  '178.jpg',
#  '179.jpg',
#  '180.jpg',
#  '181.jpg',
#  '182.jpg',
#  '184.jpg',
#  '185.jpg',
#  '186.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '19.jpg',
#  '190.jpg',
#  '191.jpg',
#  '193.jpg',
#  '194.jpg',
#  '195.jpg',
#  '196.jpg',
#  '197.jpg',
#  '198.jpg',
#  '199.jpg',
#  '2.jpg',
#  '20.jpg',
#  '200.jpg',
#  '201.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '31.jpg',
#  '32.jpg',
#  '33.jpg',
#  '34.jpg',
#  '35.jpg',
#  '36.jpg',
#  '37.jpg',
#  '38.jpg',
#  '39.jpg',
#  '4.jpg',
#  '40.jpg',
#  '41.jpg',
#  '42.jpg',
#  '43.jpg',
#  '44.jpg',
#  '46.jpg',
#  '47.jpg',
#  '48.jpg',
#  '49.jpg',
#  '5.jpg',
#  '50.jpg',
#  '51.jpg',
#  '52.jpg',
#  '53.jpg',
#  '54.jpg',
#  '55.jpg',
#  '56.jpg',
#  '57.jpg',
#  '58.jpg',
#  '59.jpg',
#  '6.jpg',
#  '60.jpg',
#  '61.jpg',
#  '62.jpg',
#  '63.jpg',
#  '64.jpg',
#  '65.jpg',
#  '67.jpg',
#  '68.jpg',
#  '69.jpg',
#  '7.jpg',
#  '70.jpg',
#  '71.jpg',
#  '72.jpg',
#  '73.jpg',
#  '74.jpg',
#  '75.jpg',
#  '76.jpg',
#  '78.jpg',
#  '79.jpg',
#  '8.jpg',
#  '80.jpg',
#  '81.jpg',
#  '83.jpg',
#  '84.jpg',
#  '85.jpg',
#  '86.jpg',
#  '87.jpg',
#  '88.jpg',
#  '89.jpg',
#  '9.jpg',
#  '90.jpg',
#  '91.jpg',
#  '92.jpg',
#  '94.jpg',
#  '95.jpg',
#  '96.jpg',
#  '97.jpg',
#  '98.jpg',
#  '99.jpg']

# %%
from keras.preprocessing import image

images_list = []
for img in images:
  img_path = f'./{img}'
  img = image.load_img(img_path, target_size=(200,200))
  x = image.img_to_array(img)
  images_list.append(x)

images_list = np.array(images_list)
images_list
# Out:
# array([[[[165., 165., 165.],
#          [165., 165., 165.],
#          [165., 165., 165.],
#          ...,
#          [177., 177., 177.],
#          [177., 177., 177.],
#          [177., 177., 177.]],
#
#         [[165., 165., 165.],
#          [165., 165., 165.],
#          [165., 165., 165.],
#          ...,
#          [177., 177., 177.],
#          [177., 177., 177.],
#          [177., 177., 177.]],
#
#         [[165., 165., 165.],
#          [165., 165., 165.],
#          [166., 166., 166.],
#          ...,
#          [177., 177., 177.],
#          [177., 177., 177.],
#          [177., 177., 177.]],
#
#         ...,
#
#         [[153., 153., 153.],
#          [153., 153., 153.],
#          [153., 153., 153.],
#          ...,
#          [150., 150., 150.],
#          [150., 150., 150.],
#          [150., 150., 150.]],
#
#         [[153., 153., 153.],
#          [153., 153., 153.],
#          [153., 153., 153.],
#          ...,
#          [150., 150., 150.],
#          [150., 150., 150.],
#          [150., 150., 150.]],
#
#         [[153., 153., 153.],
#          [153., 153., 153.],
#          [153., 153., 153.],
#          ...,
#          [150., 150., 150.],
#          [150., 150., 150.],
#          [150., 150., 150.]]],
#
#
#        [[[177., 177., 177.],
#          [177., 177., 177.],
#          [177., 177., 177.],
#          ...,
#          [ 41.,  41.,  41.],
#          [ 49.,  49.,  49.],
#          [ 49.,  49.,  49.]],
#
#         [[177., 177., 177.],
#          [176., 176., 176.],
#          [176., 176., 176.],
#          ...,
#          [ 40.,  40.,  40.],
#          [ 47.,  47.,  47.],
#          [ 48.,  48.,  48.]],
#
#         [[176., 176., 176.],
#          [176., 176., 176.],
#          [176., 176., 176.],
#          ...,
#          [ 38.,  38.,  38.],
#          [ 45.,  45.,  45.],
#          [ 45.,  45.,  45.]],
#
#         ...,
#
#         [[174., 174., 174.],
#          [174., 174., 174.],
#          [171., 171., 171.],
#          ...,
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.]],
#
#         [[179., 179., 179.],
#          [179., 179., 179.],
#          [178., 178., 178.],
#          ...,
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.]],
#
#         [[180., 180., 180.],
#          [181., 181., 181.],
#          [179., 179., 179.],
#          ...,
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.],
#          [  4.,   4.,   4.]]],
#
#
#        [[[128., 128., 128.],
#          [129., 129., 129.],
#          [128., 128., 128.],
#          ...,
#          [106., 106., 106.],
#          [107., 107., 107.],
#          [107., 107., 107.]],
#
#         [[128., 128., 128.],
#          [128., 128., 128.],
#          [128., 128., 128.],
#          ...,
#          [107., 107., 107.],
#          [107., 107., 107.],
#          [107., 107., 107.]],
#
#         [[128., 128., 128.],
#          [128., 128., 128.],
#          [128., 128., 128.],
#          ...,
#          [106., 106., 106.],
#          [107., 107., 107.],
#          [107., 107., 107.]],
#
#         ...,
#
#         [[ 96.,  96.,  96.],
#          [ 96.,  96.,  96.],
#          [ 94.,  94.,  94.],
#          ...,
#          [ 80.,  80.,  80.],
#          [ 83.,  83.,  83.],
#          [ 83.,  83.,  83.]],
#
#         [[ 96.,  96.,  96.],
#          [ 95.,  95.,  95.],
#          [ 94.,  94.,  94.],
#          ...,
#          [ 80.,  80.,  80.],
#          [ 83.,  83.,  83.],
#          [ 83.,  83.,  83.]],
#
#         [[ 95.,  95.,  95.],
#          [ 95.,  95.,  95.],
#          [ 93.,  93.,  93.],
#          ...,
#          [ 81.,  81.,  81.],
#          [ 83.,  83.,  83.],
#          [ 83.,  83.,  83.]]],
#
#
#        ...,
#
#
#        [[[ 60.,  60.,  60.],
#          [ 58.,  58.,  58.],
#          [ 56.,  56.,  56.],
#          ...,
#          [ 73.,  73.,  73.],
#          [ 72.,  72.,  72.],
#          [ 56.,  56.,  56.]],
#
#         [[ 56.,  56.,  56.],
#          [ 56.,  56.,  56.],
#          [ 55.,  55.,  55.],
#          ...,
#          [ 74.,  74.,  74.],
#          [ 78.,  78.,  78.],
#          [ 49.,  49.,  49.]],
#
#         [[ 54.,  54.,  54.],
#          [ 55.,  55.,  55.],
#          [ 55.,  55.,  55.],
#          ...,
#          [ 66.,  66.,  66.],
#          [ 77.,  77.,  77.],
#          [ 44.,  44.,  44.]],
#
#         ...,
#
#         [[  1.,   1.,   1.],
#          [  1.,   1.,   1.],
#          [  1.,   1.,   1.],
#          ...,
#          [  2.,   2.,   2.],
#          [  9.,   9.,   9.],
#          [ 16.,  16.,  16.]],
#
#         [[  1.,   1.,   1.],
#          [  1.,   1.,   1.],
#          [  1.,   1.,   1.],
#          ...,
#          [  3.,   3.,   3.],
#          [ 11.,  11.,  11.],
#          [ 21.,  21.,  21.]],
#
#         [[  1.,   1.,   1.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          ...,
#          [  5.,   5.,   5.],
#          [ 15.,  15.,  15.],
#          [ 25.,  25.,  25.]]],
#
#
#        [[[ 76.,  76.,  76.],
#          [111., 111., 111.],
#          [ 42.,  42.,  42.],
#          ...,
#          [ 36.,  36.,  36.],
#          [ 27.,  27.,  27.],
#          [ 35.,  35.,  35.]],
#
#         [[105., 105., 105.],
#          [ 59.,  59.,  59.],
#          [ 67.,  67.,  67.],
#          ...,
#          [ 29.,  29.,  29.],
#          [ 26.,  26.,  26.],
#          [ 32.,  32.,  32.]],
#
#         [[119., 119., 119.],
#          [ 42.,  42.,  42.],
#          [ 79.,  79.,  79.],
#          ...,
#          [ 33.,  33.,  33.],
#          [ 35.,  35.,  35.],
#          [ 29.,  29.,  29.]],
#
#         ...,
#
#         [[ 35.,  35.,  35.],
#          [ 37.,  37.,  37.],
#          [ 48.,  48.,  48.],
#          ...,
#          [ 72.,  72.,  72.],
#          [150., 150., 150.],
#          [113., 113., 113.]],
#
#         [[ 36.,  36.,  36.],
#          [ 46.,  46.,  46.],
#          [ 52.,  52.,  52.],
#          ...,
#          [ 75.,  75.,  75.],
#          [195., 195., 195.],
#          [127., 127., 127.]],
#
#         [[ 34.,  34.,  34.],
#          [ 35.,  35.,  35.],
#          [ 50.,  50.,  50.],
#          ...,
#          [ 64.,  64.,  64.],
#          [129., 129., 129.],
#          [166., 166., 166.]]],
#
#
#        [[[106., 106., 106.],
#          [104., 104., 104.],
#          [106., 106., 106.],
#          ...,
#          [ 12.,  12.,  12.],
#          [  2.,   2.,   2.],
#          [  9.,   9.,   9.]],
#
#         [[104., 104., 104.],
#          [105., 105., 105.],
#          [106., 106., 106.],
#          ...,
#          [ 11.,  11.,  11.],
#          [  9.,   9.,   9.],
#          [  9.,   9.,   9.]],
#
#         [[105., 105., 105.],
#          [107., 107., 107.],
#          [106., 106., 106.],
#          ...,
#          [ 17.,  17.,  17.],
#          [  8.,   8.,   8.],
#          [  7.,   7.,   7.]],
#
#         ...,
#
#         [[ 16.,  16.,  16.],
#          [ 14.,  14.,  14.],
#          [ 11.,  11.,  11.],
#          ...,
#          [ 23.,  23.,  23.],
#          [ 25.,  25.,  25.],
#          [ 48.,  48.,  48.]],
#
#         [[ 22.,  22.,  22.],
#          [ 18.,  18.,  18.],
#          [ 14.,  14.,  14.],
#          ...,
#          [ 17.,  17.,  17.],
#          [ 21.,  21.,  21.],
#          [ 33.,  33.,  33.]],
#
#         [[ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          ...,
#          [ 11.,  11.,  11.],
#          [ 17.,  17.,  17.],
#          [ 32.,  32.,  32.]]]], dtype=float32)

# %%
images_list.shape
# Out:
# (185, 200, 200, 3)

# %%
def converter(x):
    #x has shape (batch, width, height, channels)
    return (0.21 * x[:,:,:,:1]) + (0.72 * x[:,:,:,1:2]) + (0.07 * x[:,:,:,-1:])

# %%
images_gray = converter(images_list)

x_train = images_gray[:]
# x_test = images_gray[120:]

x_train = x_train.astype('float32') / 255.
# x_test = x_test.astype('float32') / 255.

# %%
vae = Model(input_img, y)
vae.compile(optimizer='rmsprop', loss=None)
vae.summary()

vae.fit(x=x_train, y=None,
        shuffle=True,
        epochs=10,
        batch_size=batch_size)
        # validation_data=(x_test, None))
# Out:
# WARNING:tensorflow:Output custom_variational_layer missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to custom_variational_layer.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 64) 18496       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 100, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 640000)       0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           20480032    flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            66          dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            66          dense[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# model (Functional)              (None, 200, 200, 1)  1938753     lambda[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer (Custo (None, 200, 200, 1)  0           input_1[0][0]
#                                                                  model[0][0]
# ==================================================================================================
# Total params: 22,511,589
# Trainable params: 22,511,589
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 185 samples
# Epoch 1/10
# 185/185 [==============================] - 3s 19ms/sample - loss: 0.6420
# Epoch 2/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6175
# Epoch 3/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6160
# Epoch 4/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6164
# Epoch 5/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6114
# Epoch 6/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6103
# Epoch 7/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6097
# Epoch 8/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6081
# Epoch 9/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6111
# Epoch 10/10
# 185/185 [==============================] - 2s 12ms/sample - loss: 0.6068

# %% [markdown]
# MNIST 데이터셋으로 모델의 훈련을 마치면 디코더 네트워크를 사용하여 잠재 공간의 임의의 벡터를 이미지로 변환할 수 있습니다:

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm

# Display a 2D manifold of the digits
n = 15  # 15 × 15 숫자의 그리드를 출력합니다
digit_size = 200
figure = np.zeros((digit_size * n, digit_size * n))
# 싸이파이 ppf 함수를 사용하여 일정하게 떨어진 간격마다 잠재 변수 z의 값을 만듭니다
# 잠재 공간의 사전 확률은 가우시안입니다
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        z_sample = np.tile(z_sample, batch_size).reshape(batch_size, 2)
        x_decoded = decoder.predict(z_sample, batch_size=batch_size)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()

# %%
x_decoded = decoder.predict( np.array([[1, 4]]))
digit = x_decoded.reshape(200, 200)
plt.figure(figsize=(10, 10))
plt.imshow(digit, cmap='Greys_r')
plt.show()

# %% [markdown]
# 샘플링된 숫자의 그리드는 다른 숫자 클래스 사이에서 완벽하게 연속된 분포를 보여줍니다. 잠재 공간의 한 경로를 따라서 한 숫자가 다른 숫자로 자연스럽게 바뀝니다. 이 공간의 특정 방향은 어떤 의미를 가집니다. 예를 들어 '6으로 가는 방향', '9로 가는 방향' 등입니다.
